# %%
#PROGRAM 1 :

#Write a program to find out the length of string without using len() function.

s=input("enter a string : ")
count=0
for i in s:
  count=count+1
print("length of string = ",count)
# Out:
# enter a string : python
# length of string =  6

# %%
#PROGRAM 2 :

#Write a program to count all letters, digits, and special symbols from a given string.

s = input("Enter String : ")
letters = digits = special = 0

for i in range(len(s)):
    if(s[i].isalpha()):
        letters = letters + 1
    elif(s[i].isdigit()):
        digits = digits + 1
    else:
        special = special + 1
        
print("\nTotal Number of Alphabets in this String :  ", letters)
print("Total Number of Digits in this String :  ", digits)
print("Total Number of Special Characters in this String :  ", special)
# Out:
# Please Enter your Own String : jhut9gik09___
#
# Total Number of Alphabets in this String :   7
# Total Number of Digits in this String :   3
# Total Number of Special Characters in this String :   3

# %%
#PROGRAM 3 :

#Write a python program to count the number of vowels in a string.

s = input("Enter String : ")
vowels = 0
 
for i in s                                :
    if(i == 'a' or i == 'e' or i == 'i' or i == 'o' or i == 'u' or i == 'A'
       or i == 'E' or i == 'I' or i == 'O' or i == 'U'):
        vowels = vowels + 1
 
print("Total Number of Vowels in this String = ", vowels)
# Out:
# Enter String : uvfgiaefywpi9r
# Total Number of Vowels in this String =  5

# %%
#PROGRAM 4 :

#Write a python program to calculate thr number of upercase and lowercase in a string.

string=input("Enter string:")
count1=0
count2=0
for i in string:
      if(i.islower()):
            count1=count1+1
      elif(i.isupper()):
            count2=count2+1
print("The number of lowercase characters is:")
print(count1)
print("The number of uppercase characters is:")
print(count2)
# Out:
# Enter string:niHMDyemokdk
# The number of lowercase characters is:
# 9
# The number of uppercase characters is:
# 3

# %%
#PROGRAM 5 :

#Write a python program to check whether given string is palindrome or not.

st = input("Please enter your own text : ")

if(st == st[:: - 1]):
   print("This is a Palindrome String")
else:
   print("This is Not")
# Out:
# Please enter your own text : mbujubm
# This is a Palindrome String
