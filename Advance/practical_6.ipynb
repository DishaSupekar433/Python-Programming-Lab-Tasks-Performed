# %%
class person:
  name='raju'
  age=20
  def talk(cls):
    print(cls.name)
    print(cls.age)
p1=person()
p1.talk()
# Out:
# raju
# 20

# %%
class person:
  def __init__(self,name):
    self.name=name
  def dis(self):
    print(self.name)
a=person("John")
a.dis()
# Out:
# John

# %%
from os import name
class person:
  def __init__(self,name):
    self.name=name
    print(self.name)
a=person("John")
# Out:
# John

# %%
class bankaccount :
  
  def __init__(self):
    self.balance=0

  def deposit(self):
    a=(int(input("Enter the amount to be deposited : ")))
    self.balance+=a
    print("Amount deposited : ",a)

  def withdraw(self):
    x=int(input("How much amount you want to withdraw ? :"))
    if self.balance<x:
      print("Insufficient balance in account")
    else :
      self.balance=self.balance-x
      print("Final balance = ",self.balance)

balance=bankaccount()
balance.deposit()
balance.withdraw()
# Out:
# Enter the amount to be deposited : 20000
# Amount deposited :  20000
# How much amount you want to withdraw ? :3000
# Final balance =  17000

# %%
class Employee:
    def __init__(self, name, id,address):
        self.name = name
        self.id = id
        self.address = address
         
    def details(self):
        print("Employee Name:",  self.name)
        print("Employee id:", self.id)
        print("Employee address:",self.address)
        
    def salary(self):
      s=int(input("salary : "))
      if s>3000:
          print("Grade A")
      elif s>2000 and s<3000:
          print("Grade B")
      else :
          print("Grade C")
 
emp = Employee("Shduh", 36,"svfhdiu")
emp.details()
emp.salary()
# Out:
# Employee Name: Shduh
# Employee id: 36
# Employee address: svfhdiu
# salary : 4990
# Grade A

# %%
class employee:
    def __init__(self):
         name=""
         id=""
         address=""
         salary=0

    def details(self):
      name=input("Employee name : ")
      id=input("Employee id : ")
      add=input("Address : ")
        
    def salary(self):
      s=int(input("Salary : "))
      if s>30000 :
          print("Grade A")
      elif s>20000 and s<30000 :
          print("Grade B")
      else :
          print("Grade C")
 
emp = employee()
emp.details()
emp.salary()
# Out:
# Employee name : Joe
# Employee id : 69
# Address : LA, USA
# Salary : 4500
# Grade C

# %%
class student:
    def __init__(self):
         name=""
         id=""
         address=""
         marks=0

    def details(self):
      name=input("Student's name : ")
      id=input("Student's id : ")
      add=input("Student's address : ")
        
    def marks(self):
      m=int(input("Marks : "))
      if m>=80 :
          print("Grade A")
      elif m>=60 and m<80 :
          print("Grade B")
      elif m>=35 and m<60 :
          print("Grade C")
      else :
          print("Grade D")
 
std = student()
std.details()
std.marks()
# Out:
# Student's name : Karl
# Student's id : 3154
# Student's address : Dublin, Ireland
# Marks : 79
# Grade B
