# %%
#inheritance
#how to private a variable

class person:
  def __init__(self):
    self.a=10
    self._b=30
  def dis(self):
      print(self.a)
      print(self._b)
p=person()
p.dis()
# Out:
# 10
# 30

# %%
#inheritance   parent class= base class  child=derived 
class person:
  def __init__(self,fname,lname):
    self.fname=fname
    self.lname=lname

  def display(self):
    print(self.fname,self.lname)

class student(person) :
  pass

x=student("mike","olsenn")     
x.display()
# Out:
# mike olsenn

# %%
class A:
  def sum(self,a,b):
    c=a+b
    print("Addition : ",c)

class B(A):
  def mul (self,a,b):
    c=a*b
    print("Multiplication : ",c)



c=B()
c.sum(60,59)
c.mul(47,8)
# Out:
# Addition :  119
# Multiplication :  376

# %%
#OVERWRITE

class BC:
  def disp(self):
    print("Base class method")

class DC(BC):
  def disp(self):
    print("Derived class method")

ob=DC() 
ob.disp()
# Out:
# Derived class method

# %%
class person:
  def __init__(self,fname,lname):
    self.fname=fname
    self.lname=lname

  def display(self):
    print(self.fname,self.lname)

class student(person) :
  def __init__(self,fname,lname):
    super(). __init__(fname,lname)
    self.gradutationyear=2025
    print(self.gradutationyear)

x=student("mike","olsenn")     
x.display()
# Out:
# 2025
# mike olsenn

# %%
class Fish :
  def __init__(self,name,no_of_eyes=2,last_name="Fish"):
    self.name=name
    self.no_of_eyes=no_of_eyes
    self.last_name=last_name
  def swim(self):
    print("The Fish is Swimming")
class ClownFish(Fish) :
  def __init__(self,color="Blue"):
    self.color=color
    super().__init__(self)
  def live_with_anemone(self):
    print("The Clownfish is coexisting with Sea Anemone.")
Casey=ClownFish()
Casey.name="Casey"
print(Casey.name+" "+Casey.last_name+" has",Casey.no_of_eyes,"eyes")
print("Color is",Casey.color)
Casey.swim()
Casey.live_with_anemone()
# Out:
# Casey Fish has 2 eyes
# Color is Blue
# The Fish is Swimming
# The Clownfish is coexisting with Sea Anemone.

# %%
class A :
  def add(self,x,y):
    self.x=x
    self.y=y
    print("The addition is : ",self.x+self.y)
class B(A) : #Single Inheritance
  def sub(self,x,y):
    self.x=x
    self.y=y
    print("The subtraction is : ",self.x-self.y)
#read data into a and b
a=int(input("Enter value of : "))
b=int(input("Enter value of : "))
#create object from derived class
ob=B()
ob.add(a,b)
ob.sub(a,b)
# Out:
# Enter value of : 4
# Enter value of : 1
# The addition is :  5
# The subtraction is :  3

# %%
class A :
  def add(self,x,y):
    self.x=x
    self.y=y
    print("The addition is : ",self.x+self.y)
class B(A) : #Single Inheritance
  def sub(self,x,y):
    self.x=x
    self.y=y
    print("The subtraction is : ",self.x-self.y)
ob=B()
ob.add(4,5)
ob.sub(7,2)
# Out:
# The addition is :  9
# The subtraction is :  5

# %%
class A :
  def add(self,x,y):
    self.x=x
    self.y=y
    print("The addition is : ",self.x+self.y)
class B(A) : #Single Inheritance
  def sub(self,x,y):
    self.x=x
    self.y=y
    print("The subtraction is : ",self.x-self.y)
class C(B) : #Multi-level Inheritance
  def mul(self,x,y):
    self.x=x
    self.y=y
    print("The multiplication is : ",self.x*self.y)
#read data into a and b
a=int(input("Enter value of : "))
b=int(input("Enter value of : "))
#create object from derived class
ob=C()
ob.add(a,b)
ob.sub(a,b)
ob.mul(a,b)
# Out:
# Enter value of : 5
# Enter value of : 3
# The addition is :  8
# The subtraction is :  2
# The multiplication is :  15

# %%
class Fish:
  def community(self):
    print("i am inside Fish Class")
class mammal:
  def protect_mammal(self):
    print("I am inside mammal class.")
class GoldFish(Fish, mammal):
  def protect_gf(self):
    print("I am inside GoldFish class.")
obj=GoldFish() # Creating an object of GoldFish Class
obj.community()
obj.protect_mammal()
obj.protect_gf()
# Out:
# i am inside Fish Class
# I am inside mammal class.
# I am inside GoldFish class.

# %%
#multiple inheritance
class A:
  def m1(self):
    print("Class A")
class B:
  def m2(self):
    print("Class B")
class C(A,B):
  def m3(self):
    print("Class C (A and B)")
obj=C()
obj.m1()
obj.m2()
obj.m3()
# Out:
# Class A
# Class B
# Class C (A and B)

# %%
#single parent multiple child class 
class P:
  def m(self):
    print("Parent class")
class C1(P):
  def m1(self):
    print("Derived class 1")
class C2(P):
  def m2(self):
    print("Derived class 2")
class C3(P):
  def m3(self):
    print("Derived class 3")   
obj1=C1()
obj2=C2()
obj3=C3()
obj1.m()
obj1.m1()
obj2.m()
obj2.m2()
obj3.m()
obj3.m3()
# Out:
# Parent class
# Derived class 1
# Parent class
# Derived class 2
# Parent class
# Derived class 3

# %%
#hybrid inheritance
#combination of all types of inheritance

class A:
  def a(self):
    print("Class A")
class B(A):
  def b(self):
    print("Class B")
class C:
  def c(self):
    print("Class C")
class D(B,C):
  def d(self):
    print("Class D")   
obj_a=A()
obj_b=B()
obj_c=C()
obj_d=D()
obj_a.a()
obj_b.b()
obj_b.a()
obj_c.c()
obj_d.d()
obj_d.b()
obj_d.a()
# Out:
# Class A
# Class B
# Class A
# Class C
# Class D
# Class B
# Class A

# %%
class A:
  def a(self):
    print("Class A")
class B(A):
  def b(self):
    print("Class B")
class C:
  def c(self):
    print("Class C")
class D(B,C):
  def d(self):
    print("Class D")   
obj_a=A()
obj_b=B()
obj_c=C()
obj_d=D()
obj_a.a()
obj_b.b()
obj_b.a()
obj_c.c()
obj_d.d()
obj_d.b()
obj_d.a()
# Out:
# Class A
# Class B
# Class A
# Class C
# Class D
# Class B
# Class A

# %%
#use of len() function
a = "HGcsdhY" 
print("String : ",a)
print("Length of string is : ",len(a))
b=[1,5,'u','p']
print("List : ",b)
print("Length of list is : ",len(b))
c={9, 5, 6, 'e', 'W'}
print("Dictionary : ",c)
print("Length of dictionary is : ",len(c))
# Out:
# String :  HGcsdhY
# Length of string is :  7
# List :  [1, 5, 'u', 'p']
# Length of list is :  4
# Dictionary :  {'W', 5, 6, 9, 'e'}
# Length of dictionary is :  5

# %%
#Make a class Employee with a name and salary. Make a class Manager inherit from Employee. 
#Add an instance variable, named department. Write a method that prints manager's name, department and salary. 
#Make a class Executive inherit from Manager. Write a method that prints the string "Executive" 
#followed by the information stored in the Manager super class object.

class Employee :
  def __init__(self,name,salary) :
    self.name = name
    self.salary = salary
class Manager(Employee) : 
  def __init__(self,department) :
    self.department = department

  def print_info(self) :
    print("Name : ",self.name)
    print("Salary : ",self.salary)
    print("Department : ",self.department)

class Executive(Manager) : 
  def __init__(self) :
    print("Executive")
    
obj=Executive()
obj.name = input("Enter name of the employee : ")
obj.salary=int(input("Enter salary of the employee : "))
obj.department=input("Enter department : ")
obj.print_info()
# Out:
# Executive
# Enter name of the employee : a
# Enter salary of the employee : 587
# Enter department : vh
# Name :  a
# Salary :  587
# Department :  vh
