# %%
            with open('NEWFILE.txt' ,'r')as file1:
  f=file1.read()
  print(f)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files
file = open('NEWFILE.txt','r')
for each in file:
  print(each)

# %%
with open('/content/NEWFILE.txt' ,'r')as file1:
  f=file1.read()
  print(f)
# Out:
# HI
# HOW ARE YOU ?

# %%
from google.colab import files
file = open('/content/NEWFILE.txt','r')
for each in file:
  print(each)
# Out:
# HI
#
# HOW ARE YOU ?

# %%
with open("/content/new.txt","w") as file1:
  f1=file1.write("hey, i'm fine \n")

# %%
with open("/content/new.txt", "a") as file1:
    file1.write("hello")

# %%
with open("myfile.txt", "w") as file_ :
  F = ["A\n", "B\n", "C"]
  file_.writelines(F)

# %%
with open('myfile.txt' ,'r')as file1:
  f=file1.read()
  print(f)
# Out:
# A
# B
# C

# %%
with open("another_file.txt", "a") as file1:
  file1.write("alright!\n")

with open('another_file.txt' ,'r')as file1:
  f=file1.read()
  print(f)
# Out:
# hey, i'm fine
# 12345
# alright!

# %%
with open('test.txt' ,'r')as file1:
  f=file1.read()
  print(f)
# Out:
# hi!

# %%
with open('test.txt' ,'a')as file1:
  file1.write("how are you?")

with open('test.txt' ,'r')as file1:
  f=file1.read()
  print(f)
# Out:
# hi!
# how are you?

# %%
try :
  with open('example.txt' ,'r')as file1:
    f=file1.read()
    print(f)

  with open('example.txt' ,'w')as file1:
    f=file1.write("hey")

  with open('example.txt' ,'a')as file1:
    file1.write("abc")

except FileNotFoundError :
  print("No such file exist")
# Out:
# No such file exist

# %%
with open('example.txt' ,'r')as file1:
    f=file1.read()
    print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-5b7e8f957fb0> in <module>
# ----> 1 with open('example.txt' ,'r')as file1:
#       2     f=file1.read()
#       3     print(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'
