# %%
import datetime

datetime_=datetime.datetime.now()
print("Current date and time is : ",datetime_)
# Out:
# Current date and time is :  2022-09-29 05:21:50.976091

# %%
import datetime
import pytz

datetime_=datetime.datetime.now(pytz.timezone("Asia/Kolkata"))
print("Current date and time : ",datetime_)
# Out:
# Current date and time :  2022-09-29 10:54:46.674863+05:30
